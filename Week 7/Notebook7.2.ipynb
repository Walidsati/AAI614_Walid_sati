# %% [markdown]
# <a href="https://colab.research.google.com/github/Walidsati/AAI614_Walid_sati/blob/main/Week%207/Notebook7.2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AAI614: Data Science & its Applications
#
# *Notebook 7.2: Accelerating Data Science*
#
# <a href="https://colab.research.google.com/github/harmanani/AAI614/blob/main/Week%207/Notebook7.2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# Source: Data Science with Python and Dask

# %% [markdown]
# ### Examining the Metadata of Dask Objects

# %% [markdown]
# You would need for this lab to downlaod the data and store on your local disk as it is arond 2GB with 42.3M Rows of Parking Ticket Data.  The data can be downloaded from [Kaggle](http://www.kaggle.com/new-york-city/nyc-parking-tickets/)

# %%
# !pip install dask
import dask.dataframe as dd
from dask.diagnostics import ProgressBar
from matplotlib import pyplot as plt

df = dd.read_csv('Parking_Violations_Issued_-_Fiscal_Year_2017.csv',
                  dtype={'House Number': 'object', 'Time First Observed': 'object'})

df
# Out:
# Requirement already satisfied: dask in /usr/local/lib/python3.10/dist-packages (2024.10.0)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.10/dist-packages (from dask) (8.1.7)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from dask) (3.1.0)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.10/dist-packages (from dask) (2024.10.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from dask) (24.2)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from dask) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from dask) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from dask) (0.12.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /usr/local/lib/python3.10/dist-packages (from dask) (8.5.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.13.0->dask) (3.21.0)
# Requirement already satisfied: locket in /usr/local/lib/python3.10/dist-packages (from partd>=1.4.0->dask) (1.0.0)
# Dask DataFrame Structure:
#               Summons Number Plate ID Registration State Plate Type Issue Date Violation Code Vehicle Body Type Vehicle Make Issuing Agency Street Code1 Street Code2 Street Code3 Vehicle Expiration Date Violation Location Violation Precinct Issuer Precinct Issuer Code Issuer Command Issuer Squad Violation Time Time First Observed Violation County Violation In Front Of Or Opposite House Number Street Name Intersecting Street Date First Observed Law Section Sub Division Violation Legal Code Days Parking In Effect     From Hours In Effect To Hours In Effect Vehicle Color Unregistered Vehicle? Vehicle Year Meter Number Feet From Curb Violation Post Code Violation Description No Standing or Stopping Violation Hydrant Violation Double Parking Violation
# npartitions=1
#                        int64   string             string     string     string          int64            string       string         string        int64        int64        int64                   int64            float64              int64           int64       int64         string       string         string              string           string                            string       string      string              string               int64       int64       string               string                     string               string             string        string               float64        int64       string          int64              string                string                           float64           float64                  float64
#                          ...      ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...                 ...              ...                               ...          ...         ...                 ...                 ...         ...          ...                  ...                        ...                  ...                ...           ...                   ...          ...          ...            ...                 ...                   ...                               ...               ...                      ...
# Dask Name: to_pyarrow_string, 2 graph layers

# %%
missing_values = df.isnull().sum()
missing_values
# Out:
# Dask Series Structure:
# npartitions=1
# Date First Observed    int64
# Violation Time           ...
# dtype: int64
# Dask Name: to_pyarrow_string, 6 graph layers

# %%
missing_count = ((missing_values / df.index.size) * 100)
missing_count
# Out:
# Dask Series Structure:
# npartitions=1
# Date First Observed    float64
# Violation Time             ...
# dtype: float64
# Dask Name: mul, 11 graph layers

# %% [markdown]
# ### Running Computations with the Compute Method

# %%
with ProgressBar():
  missing_count_pct = missing_count.compute()
missing_count_pct
# Out:
# [########################################] | 100% Completed | 8.99 s
# Summons Number                         0.000000
# Plate ID                               0.006725
# Registration State                     0.000000
# Plate Type                             0.000000
# Issue Date                             0.000000
# Violation Code                         0.000000
# Vehicle Body Type                      0.379181
# Vehicle Make                           0.670076
# Issuing Agency                         0.000000
# Street Code1                           0.000000
# Street Code2                           0.000000
# Street Code3                           0.000000
# Vehicle Expiration Date                0.000000
# Violation Location                    18.466239
# Violation Precinct                     0.000000
# Issuer Precinct                        0.000000
# Issuer Code                            0.000000
# Issuer Command                        18.373643
# Issuer Squad                          18.383126
# Violation Time                         0.000517
# Time First Observed                   92.135484
# Violation County                       0.354351
# Violation In Front Of Or Opposite     19.246156
# House Number                          20.443016
# Street Name                            0.036039
# Intersecting Street                   69.400656
# Date First Observed                    0.000000
# Law Section                            0.000000
# Sub Division                           0.006380
# Violation Legal Code                  81.626013
# Days Parking In Effect                24.460887
# From Hours In Effect                  50.201575
# To Hours In Effect                    50.201575
# Vehicle Color                          1.321875
# Unregistered Vehicle?                 89.846431
# Vehicle Year                           0.000000
# Meter Number                          83.661244
# Feet From Curb                         0.000000
# Violation Post Code                   28.526867
# Violation Description                 10.152879
# No Standing or Stopping Violation    100.000000
# Hydrant Violation                    100.000000
# Double Parking Violation             100.000000
# dtype: float64

# %%
columns_to_drop = missing_count_pct[missing_count_pct > 60].index
with ProgressBar():
    df_dropped = df.drop(columns_to_drop, axis=1).persist()
# Out:
# [########################################] | 100% Completed | 7.00 s

# %% [markdown]
# ### Visualizing a Simple DAG using Dask Delayed Objects

# %%
import dask.delayed as delayed
from dask.diagnostics import ProgressBar

def inc(i):
    return i + 1

def add(x, y):
    return x + y

x = delayed(inc)(1)
y = delayed(inc)(2)
z = delayed(add)(x, y)

z.visualize()

# %% [markdown]
# ### Visualizing More Complex DAGs with Loops and Collections

# %%
# Listing 2.7
def add_two(x):
    return x + 2

def sum_two_numbers(x,y):
    return x + y

def multiply_four(x):
    return x * 4

data = [1, 5, 8, 10]

step1 = [delayed(add_two)(i) for i in data]
total = delayed(sum)(step1)
total.visualize()

# %%
def add_two(x):
    return x + 2

def sum_two_numbers(x,y):
    return x + y

def multiply_four(x):
    return x * 4

data = [1, 5, 8, 10]

step1 = [delayed(add_two)(i) for i in data]
step2 = [delayed(multiply_four)(j) for j in step1]
total = delayed(sum)(step2)
total.visualize()

# %%
data2 = [delayed(sum_two_numbers)(k, total) for k in data]
total2 = delayed(sum)(data2)
total2.visualize()

# %%
total_persisted = total.persist()
total_persisted.visualize()

# %%
data2 = [delayed(sum_two_numbers)(l, total_persisted) for l in data]
total2 = delayed(sum)(data2)
total2.visualize()

# %%
missing_count.visualize()
