# %% [markdown]
# <a href="https://colab.research.google.com/github/Walidsati/AAI614_Walid_sati/blob/main/Week%203/Data_Scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import ssl
import pandas as pd

# %%
html = urlopen('https://www.canada.ca/en/public-health/services/surveillance/respiratory-virus-detections-canada/2018-2019/respiratory-virus-detections-isolations-week-01-ending-january-5-2019.html')
bs = BeautifulSoup(html, 'html.parser')

# %%
table = bs.find_all('table')[1]
table
# Out:
# <table class="table table-condensed table-striped table-hover table-bordered small" id="t2">
# <caption class="text-left wb-inv">
#       Table 2: Respiratory Virus Detections/Isolations for the period August 26, 2018 - January 5, 2019 (Reporting Weeks 201835-201901)
#       </caption>
# <thead>
# <tr class="bg-primary">
# <th scope="col">Reporting Laboratory</th>
# <th scope="col">Flu Tested</th>
# <th scope="col">A(H1N1)pdm09 Positive</th>
# <th scope="col">A(H3) Positive</th>
# <th scope="col">A(UnS) Positive</th>
# <th scope="col">Total Flu A Positive</th>
# <th scope="col">Total Flu B Positive</th>
# <th scope="col">RSV Tested</th>
# <th scope="col">RSV Positive</th>
# <th scope="col">PIV Tested</th>
# <th scope="col">PIV 1 Positive</th>
# <th scope="col">PIV 2 Positive</th>
# <th scope="col">PIV 3 Positive</th>
# <th scope="col">PIV 4 Positive</th>
# <th scope="col">Other PIV Positive</th>
# <th scope="col">Adeno Tested</th>
# <th scope="col">Adeno Positive</th>
# ...

# %%
headers = []
for header in table.find_all('th'):
    headers.append(header.text)

data = []
for row in table.find_all('tr'):
    row_data = []
    for cell in row.find_all('td'):
        row_data.append(cell.text)
    data.append(row_data)

# %%
table2= pd.DataFrame(data, columns = headers)
table2.head()
# Out:
#    Reporting Laboratory Flu Tested A(H1N1)pdm09 Positive A(H3) Positive  \
# 0                  None       None                  None           None
# 1          Newfoundland       1299                     1              0
# 2  Prince Edward Island        307                    38              0
# 3           Nova Scotia        864                     0              0
# 4         New Brunswick       4271                    42              1
#
#   A(UnS) Positive Total Flu A Positive Total Flu B Positive RSV Tested  \
# 0            None                 None                 None       None
# 1             113                  114                    1       1299
# 2               0                   38                    0        305
# 3              52                   52                    1        869
# 4             715                  758                    2       4274
#
#   RSV Positive PIV Tested  ... PIV 4 Positive Other PIV Positive Adeno Tested  \
# ...

# %%
table2.tail()
# Out:
#                                  Reporting Laboratory Flu Tested  \
# 38                           Northwest    Territories        435
# 39                                            Nunavut         33
# 40                                        Territories        611
# 41                                             CANADA     110399
# 42  Specimens from YT, NT and NU are sent to refer...       None
#
#    A(H1N1)pdm09 Positive A(H3) Positive A(UnS) Positive Total Flu A Positive  \
# 38                   138              2               0                  140
# 39                     8              0               0                    8
# 40                   162              3               6                  171
# 41                  6609            395           10936                17941
# 42                  None           None            None                 None
#
#    Total Flu B Positive RSV Tested RSV Positive PIV Tested  ...  \
# ...

# %%
table2.shape
# Out:
# (43, 23)

# %%
table2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Reporting Laboratory   42 non-null     object
#  1   Flu Tested             41 non-null     object
#  2   A(H1N1)pdm09 Positive  41 non-null     object
#  3   A(H3) Positive         41 non-null     object
#  4   A(UnS) Positive        41 non-null     object
#  5   Total Flu A Positive   41 non-null     object
#  6   Total Flu B Positive   41 non-null     object
#  7   RSV Tested             41 non-null     object
#  8   RSV Positive           41 non-null     object
#  9   PIV Tested             41 non-null     object
#  10  PIV 1 Positive         41 non-null     object
#  11  PIV 2 Positive         41 non-null     object
#  12  PIV 3 Positive         41 non-null     object
#  13  PIV 4 Positive         41 non-null     object
# ...

# %%
table2 = table2.iloc[1:42]

# %%
table2
# Out:
#                    Reporting Laboratory Flu Tested A(H1N1)pdm09 Positive  \
# 1                          Newfoundland       1299                     1
# 2                  Prince Edward Island        307                    38
# 3                           Nova Scotia        864                     0
# 4                         New Brunswick       4271                    42
# 5                              Atlantic       6741                    81
# 6                    Région    Nord-Est       3551                     0
# 7           Québec-Chaudière-Appalaches       5028                     0
# 8                      Centre-du-Québec       5435                     0
# 9                      Montréal-Laval        16318                     0
# 10                      Ouest du Québec       4775                     0
# 11                           Montérégie       3288                     0
# 12                  Province of Québec       38395                     0
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

table2.to_csv('/content/drive/My Drive/table2.csv', index=False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pd.read_csv('/content/drive/My Drive/table2.csv')
# Out:
#                    Reporting Laboratory  Flu Tested  A(H1N1)pdm09 Positive  \
# 0                          Newfoundland        1299                      1
# 1                  Prince Edward Island         307                     38
# 2                           Nova Scotia         864                      0
# 3                         New Brunswick        4271                     42
# 4                              Atlantic        6741                     81
# 5                    Région    Nord-Est        3551                      0
# 6           Québec-Chaudière-Appalaches        5028                      0
# 7                      Centre-du-Québec        5435                      0
# 8                      Montréal-Laval         16318                      0
# 9                       Ouest du Québec        4775                      0
# 10                           Montérégie        3288                      0
# ...

# %%
table2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 1 to 41
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Reporting Laboratory   41 non-null     object
#  1   Flu Tested             41 non-null     object
#  2   A(H1N1)pdm09 Positive  41 non-null     object
#  3   A(H3) Positive         41 non-null     object
#  4   A(UnS) Positive        41 non-null     object
#  5   Total Flu A Positive   41 non-null     object
#  6   Total Flu B Positive   41 non-null     object
#  7   RSV Tested             41 non-null     object
#  8   RSV Positive           41 non-null     object
#  9   PIV Tested             41 non-null     object
#  10  PIV 1 Positive         41 non-null     object
#  11  PIV 2 Positive         41 non-null     object
#  12  PIV 3 Positive         41 non-null     object
#  13  PIV 4 Positive         41 non-null     object
# ...
